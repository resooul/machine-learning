# %%
from sklearn.datasets import load_digits
# %matplotlib inline
import matplotlib.pyplot as plt
digits = load_digits()

# %%
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
plt.gray() 
for i in range(5):
    plt.matshow(digits.images[i])

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(digits.data,digits.target, test_size=0.2)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predicted = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.9694444444444444

# %%
model.predict(digits.data[0:5])
# Out:
# array([0, 1, 2, 5, 4])

# %%
model.predict([digits.data[13]])
# Out:
# array([3])

# %%
y_predicted = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[136,   0,   0,   0,   2,   0,   3,   0,   0,   0],
#        [  0, 133,   0,   1,   0,   0,   7,   0,   2,   0],
#        [  2,  15, 107,  11,   0,   0,   3,   0,   4,   1],
#        [  2,   5,   4, 131,   0,   1,   0,   0,   1,   1],
#        [ 10,  18,   2,   0, 106,   0,   1,  11,   4,   1],
#        [  3,   8,   1,   4,   7, 112,   4,   1,   3,  11],
#        [  0,   2,   1,   0,   9,   0, 126,   0,   1,   0],
#        [  0,   5,   3,   1,   7,   2,   0, 120,   2,   2],
#        [  1,  21,   3,   5,   0,   4,   4,   5,  99,   1],
#        [  3,   8,   1,   7,   0,   5,   0,   3,   3, 105]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
